# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('commodity.csv')
df = df[df['Symbol'] == 'US Wheat']

# %%
#visulaize df by x=  Date, y = Open on plot 
df['Date'] = pd.to_datetime(df['Date'])
#Date >= 2015
df1 = df[df['Date'] >= '2015-01-01']
df1
# Out:
#          Symbol       Date     Open     High      Low    Close  Volume
# 28070  US Wheat 2015-01-02   589.75   591.00   574.75   581.25   38997
# 28071  US Wheat 2015-01-05   579.75   597.50   579.00   589.00   45078
# 28072  US Wheat 2015-01-06   588.00   603.50   586.00   591.75   52463
# 28073  US Wheat 2015-01-07   594.25   594.50   578.50   579.50   46079
# 28074  US Wheat 2015-01-08   580.00   581.00   565.75   567.00   49560
# ...         ...        ...      ...      ...      ...      ...     ...
# 29930  US Wheat 2022-04-04   989.50  1014.50   984.75  1010.25       0
# 29931  US Wheat 2022-04-05  1020.50  1074.00  1020.00  1045.25       0
# 29932  US Wheat 2022-04-06  1049.40  1056.40  1024.25  1041.12       0
# 29933  US Wheat 2022-04-07  1040.25  1044.50  1017.75  1020.00       0
# 29934  US Wheat 2022-04-08  1020.00  1054.25  1017.00  1051.50       0
#
# [1865 rows x 7 columns]

# %%
import matplotlib.dates as mdates

fig, ax = plt.subplots(figsize=(40,7))
ax.plot(df1['Date'], df1['Open'])
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.scatter(df1['Date'], df1['Open'])
dateFmt = mdates.DateFormatter('%Y-%m-%d')

ax.xaxis.set_major_formatter(dateFmt)


plt.show()

# %%
df2 = df[df['Date'] >= '2021-01-01']
import matplotlib.dates as mdates

fig, ax = plt.subplots(figsize=(40,7))
ax.plot(df2['Date'], df2['Open'])
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.scatter(df2['Date'], df2['Open'])
dateFmt = mdates.DateFormatter('%Y-%m-%d')

ax.xaxis.set_major_formatter(dateFmt)


plt.show()

# %%
world = pd.read_csv('wcp.csv')
world
# Out:
#                                 Country  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                                Angola
# 4                             Argentina
# ..                                  ...
# 120  Venezuela (Bolivarian Republic of)
# 121                              Global
# 122                             To whom
# 123                              Zambia
# 124                            Zimbabwe
#
#                                                  Image       1961       1962  \
# 0                                                  NaN  2279000.0  2279000.0
# 1                                                  NaN    97800.0   146407.0
# 2                                                  NaN   685723.0  1507000.0
# 3                                                  NaN    20000.0    20000.0
# 4    https://www.worldatlas.com/r/w728-h425-c728x42...  5725000.0  5700000.0
# ...

# %%
world['2016'].max()
#2016 where country = russia and ukraine
world[(world['Country'] == "Ukraine")]
world[(world['Country'] == "Russia")]
# Out:
#    Country                                              Image  1961  1962  \
# 92  Russia  https://upload.wikimedia.org/wikipedia/en/thum...   NaN   NaN
#
#     1963  1964  1965  1966  1967  1968  ...        2009        2010  \
# 92   NaN   NaN   NaN   NaN   NaN   NaN  ...  61739751.0  41507581.0
#
#           2011        2012        2013        2014        2015        2016  \
# 92  56239994.0  37719640.0  52090797.0  59711382.0  61785799.0  73294568.0
#
#           2017        2018
# 92  85863132.0  71685000.0
#
# [1 rows x 60 columns]

# %%
import plotly.express as px

fig = px.choropleth(world, locations="Country", locationmode='country names', color="2016", hover_name="Country", 
                    color_continuous_scale="Reds", range_color=(0, 1e8), title='Wheat Production', )



fig.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 14
#      11 import seaborn as sns
#      13 plt.figure(figsize=(10, 10))
# ---> 14 sns.heatmap(gold.corr(), annot=True, fmt='.2f', square=True)
#      15 plt.show()
#
# File c:\Users\melim\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\melim\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# ...
